# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import pickle
import numpy as np
import sklearn

# %%
# Pandas = Tool to manage and analyze table data in python easily
# numpy  = used for mathematical calculations
# sklearn = 1. train_test_split = used to devide data into training & Testing
#           2. GridSearchCV = used to find the best model
#           3. RandomForestClassifier = ML algo that use many decision tree to make more accurate prediction
#           4. classification_report = function that shows the performance of a classification model
#           5. pickel = used for impliment model in the website
# matplotlib = use for create graph.

# %%
print("numpy", np.__version__)
print("pandas", pd.__version__)
print("sklearn", sklearn.__version__)
# Out:
# numpy 2.0.2
# pandas 2.2.2
# sklearn 1.6.1

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
# steps

# 1. Preprocess , EDA + Feature Selection
# 2. Extract Input and Output Cols
# 3. Scale the Value
# 4. Train Test Split
# 5. Train the Model
# 6. Evaluate the Model
# 7. Deplay the Model

# %%
df.info() #give info of the data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 17   3.3  183.0
# 71   6.1  132.0
# 2    5.3  121.0
# 55   7.8  114.0
# 93   6.8  112.0
# ..   ...    ...
# 85   5.8  166.0
# 27   6.0  124.0
# 67   5.0  118.0
# 82   6.5   37.0
# 14   6.1  103.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 17    0
# 71    1
# 2     0
# 55    1
# 93    1
#      ..
# 85    1
# 27    1
# 67    0
# 82    1
# 14    0
# Name: placement, Length: 90, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_train
# Out:
# array([[-2.27738868,  1.47682269],
#        [ 0.11686225,  0.19177698],
#        [-0.56720945, -0.08538975],
#        [ 1.5705146 , -0.26176857],
#        [ 0.71542498, -0.31216252],
#        [ 0.8864429 , -0.31216252],
#        [ 0.11686225,  0.79650437],
#        [-1.67882595, -1.24445059],
#        [ 0.54440706,  0.34295882],
#        [ 0.28788017, -0.5389353 ],
#        [-0.90924529, -1.59720824],
#        [ 1.14296979, -0.21137462],
#        [ 1.82704148,  1.04847412],
#        [ 0.8864429 ,  1.87997429],
#        [ 0.80093394,  0.34295882],
#        [ 0.45889809,  0.14138303],
#        [ 0.28788017,  0.09098908],
#        [-0.99475425,  0.41854975],
#        [-0.99475425, -0.31216252],
#        [ 1.31398771,  0.84689832],
#        [-0.65271841,  2.50989866],
#        [-0.65271841,  0.19177698],
#        [-0.2251736 ,  0.4689437 ],
#        [-0.48170048,  0.2673679 ],
#        [-0.2251736 ,  1.12406504],
#        [ 0.8864429 ,  0.3681558 ],
#        [ 0.71542498, -0.86649597],
# ...

# %%
X_test = scaler.transform(X_test)

X_test
# Out:
# array([[ 0.71542498, -0.0349958 ],
#        [-1.08026322, -0.94208689],
#        [-0.48170048, -0.4381474 ],
#        [ 0.03135329, -2.00035984],
#        [ 0.03135329,  0.62012555],
#        [ 1.31398771,  0.14138303],
#        [ 0.62991602,  0.74611042],
#        [ 0.62991602,  1.45162572],
#        [ 0.03135329, -1.47122336],
#        [ 0.54440706, -0.11058672]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
                   intercept_scaling=1, l1_ratio=None, max_iter=100,
                   multi_class='auto', n_jobs=None, penalty='l2',
                   random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
                   warm_start=False)
# Out:
# LogisticRegression(multi_class='auto')

# %%
y_pred = clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-519/2200825717.py in <cell line: 0>()
# ----> 1 y_pred = clf.predict(X_test)
#
# NameError: name 'clf' is not defined

# %%
y_test
# Out:
# 0     1
# 23    0
# 81    0
# 10    1
# 33    0
# 83    1
# 74    1
# 97    1
# 45    1
# 20    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
